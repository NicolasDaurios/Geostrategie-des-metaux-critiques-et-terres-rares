# %%
import numpy as np
import pandas as pd

url = 'https://fr.wikipedia.org/wiki/Lithium'

tables = pd.read_html(url, match='Pays')
if tables:
    dfLith = tables[0]

    print(dfLith)
else:
    print("Aucune table trouvée sur la page.")
# Out:
#                                 Pays Production 2018 Production 2019  \
# 0                          Argentine           6 400           6 300
# 1                          Australie          58 800          45 000
# 2                            Bolivie              nd              nd
# 3                             Brésil             300           2 400
# 4                             Canada           2 400             200
# 5                              Chili          17 000          19 300
# 6                              Chine           7 100          10 800
# 7   République démocratique du Congo              nd              nd
# 8                 États-Unis[48],[b]             900             900
# 9                          Allemagne              nd              nd
# 10                           Mexique              nd              nd
# 11            République tchèque[49]              nd              nd
# 12                             Pérou              nd              nd
# ...

# %%
dfLith.head()
# Out:
#         Pays Production 2018 Production 2019 Production 2020 Production 2021  \
# 0  Argentine           6 400           6 300           5 900           5 970
# 1  Australie          58 800          45 000          39 700          55 300
# 2    Bolivie              nd              nd              nd              nd
# 3     Brésil             300           2 400           1 420           1 700
# 4     Canada           2 400             200              nd              nd
#
#   Production 2022 estimée Réserves prouvées Ressources estimées
# 0                   6 200         2 700 000          20 000 000
# 1                  61 000         6 200 000           7 900 000
# 2                      nd                nd          21 000 000
# 3                   2 200           250 000             730 000
# 4                     500           930 000           2 900 000

# %%
dfLith['Métal'] = 'Lithium'
dfLith.head()
# Out:
#         Pays Production 2018 Production 2019 Production 2020 Production 2021  \
# 0  Argentine           6 400           6 300           5 900           5 970
# 1  Australie          58 800          45 000          39 700          55 300
# 2    Bolivie              nd              nd              nd              nd
# 3     Brésil             300           2 400           1 420           1 700
# 4     Canada           2 400             200              nd              nd
#
#   Production 2022 estimée Réserves prouvées Ressources estimées    Métal
# 0                   6 200         2 700 000          20 000 000  Lithium
# 1                  61 000         6 200 000           7 900 000  Lithium
# 2                      nd                nd          21 000 000  Lithium
# 3                   2 200           250 000             730 000  Lithium
# 4                     500           930 000           2 900 000  Lithium

# %%
url = 'https://fr.wikipedia.org/wiki/Cobalt'

tables = pd.read_html(url, match='Pays')
if tables:
    dfCob = tables[0]

    print(dfCob)
else:
    print("Aucune table trouvée sur la page.")
# Out:
#                                 Pays    2013    2014    2015    2016    2017  \
# 0   République démocratique du Congo  54 000  63 000  63 000  64 000  73 000
# 1                             Russie   6 300   6 300   6 200   5 500   5 900
# 2                          Australie   6 400   5 980   6 000   5 500   5 030
# 3                             Canada   6 920   6 570   6 900   4 250   3 870
# 4                        Philippines       -       -   4 300   4 100   4 600
# 5                               Cuba   4 200   3 700   4 300   4 200   5 000
# 6                         Madagascar       -   3 100   3 700   3 800   3 500
# 7          Papouasie-Nouvelle-Guinée       -       -       -   2 190   3 310
# 8                     Afrique du Sud   3 000   3 000   3 000   2 300   2 300
# 9                              Maroc   2 100       -       -       -   2 200
# 10                             Chine   7 200   7 200   7 700   7 700   3 100
# ...

# %%
dfCob['Métal'] = 'Cobalt'
dfCob.head()
# Out:
#                                Pays    2013    2014    2015    2016    2017  \
# 0  République démocratique du Congo  54 000  63 000  63 000  64 000  73 000
# 1                            Russie   6 300   6 300   6 200   5 500   5 900
# 2                         Australie   6 400   5 980   6 000   5 500   5 030
# 3                            Canada   6 920   6 570   6 900   4 250   3 870
# 4                       Philippines       -       -   4 300   4 100   4 600
#
#       2018     2019    2020     2021     2022   réserves   Métal
# 0  104 000  100 000  95 000  119 000  130 000  4 000 000  Cobalt
# 1    6 100    6 300   6 300    8 000    8 900    250 000  Cobalt
# 2    4 880    5 740   5 700    5 295    5 900  1 500 000  Cobalt
# 3    3 520    3 340   3 200    4 361    3 900    220 000  Cobalt
# 4    4 600    5 100   4 700    3 600    3 800    260 000  Cobalt

# %%
url = 'https://fr.wikipedia.org/wiki/Cuivre'

tables = pd.read_html(url, match='Pays')
if tables:
    dfCui = tables[0]

    print(dfCui)
else:
    print("Aucune table trouvée sur la page.")
# Out:
#      Rang                              Pays Production 2020 (kt)  % mondial
# 0       1                             Chili                5 700        285
# 1       2                             Pérou                2 200        110
# 2       3                             Chine                1 700         85
# 3       4                        États-Unis                1 200         60
# 4       5  République démocratique du Congo                1 300         65
# 5       6                         Australie                  870         44
# 6       7                            Zambie                  830         42
# 7       8                           Mexique                  690         35
# 8       9                            Russie                  850         43
# 9      10                        Kazakhstan                  580         29
# 10     11                            Canada                  570         29
# ...

# %%
url = 'https://ressources-naturelles.canada.ca/nos-ressources-naturelles/mines-materiaux/donnees-statistiques-et-analyses-sur-lexploitation-miniere/faits-mineraux-metaux/faits-sur-laluminium/20568'

tables = pd.read_html(url, match='Bahreïn')
if tables:
    dfAlu = tables[0]

    print(dfAlu)
else:
    print("Aucune table trouvée sur la page.")
# Out:
#          Classement                 Pays Milliers de tonnes  \
# 0                 1                Chine             40 000
# 1                 2                 Inde              4 000
# 2                 3               Russie              3 700
# 3                 4               Canada              3 000
# 4                 5  Émirats arabes unis              2 700
# 5                 6              Bahreïn              1 600
# 6                 7            Australie              1 500
# 7                 8              Norvège              1 400
# 8                 9           États-Unis                860
# 9                10              Islande                750
# 10              NaN          Autres pays              9 100
# 11  Total (arrondi)                  NaN             69 000
#
#    Pourcentage du total
# 0                58,3 %
# 1                 5,8 %
# 2                 5,4 %
# 3                 4,4 %
# 4                 3,9 %
# 5                 2,3 %
# ...
